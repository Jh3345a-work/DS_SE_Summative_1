# %% [markdown]
# # SE Summative 1: NOMIS Population Estimates Analysis

# %% [markdown]
# ## Required Libraries

# %%
import requests
import pandas as pd
from io import StringIO

# %% [markdown]
# ## Data Collection

# %%
def fetch_population_data(time_value):
    BASE = "https://www.nomisweb.co.uk/api/v01"
    DATASET = "NM_2002_1"   # Population estimates dataset
    params = {
        "time": time_value,
        "measures": 20100,         # value (not percent)
        "gender": 0,               # combined total
        "c_age": 203,              # Individuals aged 16–64
    }
    url = f"{BASE}/dataset/{DATASET}.data.csv"
    resp = requests.get(url, params=params, timeout=60)
    return pd.read_csv(StringIO(resp.text))

df_23 = fetch_population_data("2023")
df_24 = fetch_population_data("2024")

# %%
df_23.head()
# Out:
#    DATE  DATE_NAME  DATE_CODE DATE_TYPE  DATE_TYPECODE  DATE_SORTORDER  \
# 0  2023       2023       2023      date              0               0
# 1  2023       2023       2023      date              0               0
# 2  2023       2023       2023      date              0               0
# 3  2023       2023       2023      date              0               0
# 4  2023       2023       2023      date              0               0
#
#     GEOGRAPHY        GEOGRAPHY_NAME GEOGRAPHY_CODE  \
# 0  1774190593            Hartlepool      E06000001
# 1  1774190594         Middlesbrough      E06000002
# 2  1774190595  Redcar and Cleveland      E06000003
# 3  1774190596      Stockton-on-Tees      E06000004
# 4  1774190597            Darlington      E06000005
#
#                                       GEOGRAPHY_TYPE  ...  MEASURES  \
# 0  local authorities: county / unitary (as of Apr...  ...     20100
# 1  local authorities: county / unitary (as of Apr...  ...     20100
# 2  local authorities: county / unitary (as of Apr...  ...     20100
# 3  local authorities: county / unitary (as of Apr...  ...     20100
# 4  local authorities: county / unitary (as of Apr...  ...     20100
#
#    MEASURES_NAME  OBS_VALUE OBS_STATUS  OBS_STATUS_NAME OBS_CONF  \
# 0          Value    58719.0          A     Normal Value        F
# 1          Value    96747.0          A     Normal Value        F
# 2          Value    81130.0          A     Normal Value        F
# 3          Value   125126.0          A     Normal Value        F
# 4          Value    67808.0          A     Normal Value        F
#
#                  OBS_CONF_NAME                                       URN  \
# 0  Free (free for publication)  Nm-2002d1d32368e1d1774190593d0d203d20100
# 1  Free (free for publication)  Nm-2002d1d32368e1d1774190594d0d203d20100
# 2  Free (free for publication)  Nm-2002d1d32368e1d1774190595d0d203d20100
# 3  Free (free for publication)  Nm-2002d1d32368e1d1774190596d0d203d20100
# 4  Free (free for publication)  Nm-2002d1d32368e1d1774190597d0d203d20100
#
#    RECORD_OFFSET RECORD_COUNT
# 0              0         3056
# 1              1         3056
# 2              2         3056
# 3              3         3056
# 4              4         3056
#
# [5 rows x 34 columns]

# %%
df_24.head()
# Out:
#    DATE  DATE_NAME  DATE_CODE DATE_TYPE  DATE_TYPECODE  DATE_SORTORDER  \
# 0  2024       2024       2024      date              0               0
# 1  2024       2024       2024      date              0               0
# 2  2024       2024       2024      date              0               0
# 3  2024       2024       2024      date              0               0
# 4  2024       2024       2024      date              0               0
#
#     GEOGRAPHY        GEOGRAPHY_NAME GEOGRAPHY_CODE  \
# 0  1774190593            Hartlepool      E06000001
# 1  1774190594         Middlesbrough      E06000002
# 2  1774190595  Redcar and Cleveland      E06000003
# 3  1774190596      Stockton-on-Tees      E06000004
# 4  1774190597            Darlington      E06000005
#
#                                       GEOGRAPHY_TYPE  ...  MEASURES  \
# 0  local authorities: county / unitary (as of Apr...  ...     20100
# 1  local authorities: county / unitary (as of Apr...  ...     20100
# 2  local authorities: county / unitary (as of Apr...  ...     20100
# 3  local authorities: county / unitary (as of Apr...  ...     20100
# 4  local authorities: county / unitary (as of Apr...  ...     20100
#
#    MEASURES_NAME  OBS_VALUE OBS_STATUS  OBS_STATUS_NAME OBS_CONF  \
# 0          Value    59988.0          A     Normal Value        F
# 1          Value    98418.0          A     Normal Value        F
# 2          Value    81553.0          A     Normal Value        F
# 3          Value   126844.0          A     Normal Value        F
# 4          Value    68652.0          A     Normal Value        F
#
#                  OBS_CONF_NAME                                       URN  \
# 0  Free (free for publication)  Nm-2002d1d32384e0d1774190593d0d203d20100
# 1  Free (free for publication)  Nm-2002d1d32384e0d1774190594d0d203d20100
# 2  Free (free for publication)  Nm-2002d1d32384e0d1774190595d0d203d20100
# 3  Free (free for publication)  Nm-2002d1d32384e0d1774190596d0d203d20100
# 4  Free (free for publication)  Nm-2002d1d32384e0d1774190597d0d203d20100
#
#    RECORD_OFFSET RECORD_COUNT
# 0              0         3056
# 1              1         3056
# 2              2         3056
# 3              3         3056
# 4              4         3056
#
# [5 rows x 34 columns]
